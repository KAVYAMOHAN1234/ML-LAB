# %% [markdown]
# <a href="https://colab.research.google.com/github/KAVYAMOHAN1234/ML-LAB/blob/main/program_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np;
X = np.array([[1, 2],
[3, 4]])

Y = np.array([[5,6], [7,8]])
print("Matrix X is :\n ",X)
print("Matrix Y is : \n",Y)

a=np.power(X,2)
print("X^2=",a)

result = a + 2 * Y
print("X^2+2*Y is \n ",result)
# Out:
# Matrix X is :
#   [[1 2]
#  [3 4]]
# Matrix Y is :
#  [[5 6]
#  [7 8]]
# X^2= [[ 1  4]
#  [ 9 16]]
# X^2+2*Y is
#   [[11 16]
#  [23 32]]
