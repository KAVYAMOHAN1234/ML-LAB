# %% [markdown]
# <a href="https://colab.research.google.com/github/KAVYAMOHAN1234/ML-LAB/blob/main/program_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([[2, 1,-2],[3,0,1],[1,1,-1]])
b = np.array([-3,5,-2])

X = np.linalg.solve(A, b)

print("Matrix A:")
print(A)

print("Vector b:")
print(b)

print("Solution for X:")
print(X)
# Out:
# Matrix A:
# [[ 2  1 -2]
#  [ 3  0  1]
#  [ 1  1 -1]]
# Vector b:
# [-3  5 -2]
# Solution for X:
# [ 1. -1.  2.]
